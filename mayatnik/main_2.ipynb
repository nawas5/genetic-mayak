# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
from sympy import *

# %%
A = 0.36
B = 7.996
C = 1.994
D = 1.193
E = 3.976

# %%
def f(y, t):#  решение дифференциального уравнения системы регулирования.
    y1,y2,y3,y4 = y
    return [y2,y3,y4,-A*y4-B*y3-C*y2-D*y1+E]
t = np. linspace(0,100,10000)
y0 = [0,1,0,0]#начальные условия
w = odeint(f, y0, t)
y1=w[:,0] # вектор значений решения
y2=w[:,1] # вектор значений производной

# %%
plt.plot(t, y1)

# %%
g = 9.8
l = 10
w0 = np.sqrt(g/l)

# %%
w0
# Out:
# 0.9899494936611666

# %%
t = np. linspace(0,50,201)
t
# Out:
# array([ 0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,  1.75,  2.  ,
#         2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,  4.  ,  4.25,
#         4.5 ,  4.75,  5.  ,  5.25,  5.5 ,  5.75,  6.  ,  6.25,  6.5 ,
#         6.75,  7.  ,  7.25,  7.5 ,  7.75,  8.  ,  8.25,  8.5 ,  8.75,
#         9.  ,  9.25,  9.5 ,  9.75, 10.  , 10.25, 10.5 , 10.75, 11.  ,
#        11.25, 11.5 , 11.75, 12.  , 12.25, 12.5 , 12.75, 13.  , 13.25,
#        13.5 , 13.75, 14.  , 14.25, 14.5 , 14.75, 15.  , 15.25, 15.5 ,
#        15.75, 16.  , 16.25, 16.5 , 16.75, 17.  , 17.25, 17.5 , 17.75,
#        18.  , 18.25, 18.5 , 18.75, 19.  , 19.25, 19.5 , 19.75, 20.  ,
#        20.25, 20.5 , 20.75, 21.  , 21.25, 21.5 , 21.75, 22.  , 22.25,
#        22.5 , 22.75, 23.  , 23.25, 23.5 , 23.75, 24.  , 24.25, 24.5 ,
#        24.75, 25.  , 25.25, 25.5 , 25.75, 26.  , 26.25, 26.5 , 26.75,
#        27.  , 27.25, 27.5 , 27.75, 28.  , 28.25, 28.5 , 28.75, 29.  ,
# ...

# %%
def ff(fi, t):#  решение дифференциального уравнения
    fi1, fi2 = fi
    return [fi2,-w0 * np.sin(fi1)]

# %%
fi0 = [np.pi/4, 0]#начальные условия
w = odeint(ff, fi0, t)
fi1 = w[:,0]
fi2 = w[:,1]

# %%
plt.plot(t, fi1, label='fi1')
plt.plot(t, fi2, label='fi2')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()

# %%
w
# Out:
# array([[ 0.        ,  0.78539816],
#        [ 0.1943349 ,  0.76130237],
#        [ 0.37681702,  0.69133325],
#        [ 0.53669707,  0.58179095],
#        [ 0.66513688,  0.44136128],
#        [ 0.75558462,  0.27939564],
#        [ 0.80378255,  0.10477607],
#        [ 0.807596  , -0.07437724],
#        [ 0.76686028, -0.2503244 ],
#        [ 0.68336665, -0.41505025],
#        [ 0.56099756, -0.5598043 ],
#        [ 0.40590715, -0.67525754],
#        [ 0.22655889, -0.75249862],
#        [ 0.03342239, -0.7846939 ],
#        [-0.16176453, -0.76876651],
#        [-0.34706696, -0.70625608],
#        [-0.51147961, -0.60288083],
#        [-0.64580029, -0.46704929],
#        [-0.74307918, -0.30810189],
#        [-0.79867777, -0.13504429],
#        [-0.81011335,  0.04388629],
#        [-0.77689138,  0.22092987],
#        [-0.70046393,  0.38816192],
#        [-0.58434383,  0.53696746],
#        [-0.43428912,  0.65806917],
#        [-0.25838003,  0.74237987],
#        [-0.06678479,  0.78258328],
# ...

# %% [markdown]
# theta''(t) + b*theta'(t) + c*sin(theta(t)) = 0

# %% [markdown]
# theta'(t) = omega(t)
# omega'(t) = -b*omega(t) - c*sin(theta(t))

# %%
def pend(y, t, b, c):
    theta, omega = y
    dydt = [omega, -b*omega - c*np.sin(theta)]
    return dydt

# %%
b = 0.25
c = 5.0

# %%
y0 = [np.pi - 0.1, 0.0]

# %%
t = np.linspace(0, 10, 101)

# %%
sol = odeint(pend, y0, t, args=(b, c))

# %%
plt.plot(t, sol[:, 0], 'b', label='theta(t)')
plt.plot(t, sol[:, 1], 'g', label='omega(t)')
plt.legend(loc='best')
plt.xlabel('t')
plt.grid()
plt.show()

# %%
def se_solve(Y,x):
    """
    Функция, задающая систему дифференциальных уравнений
    """
    return [Y[1],(-w0 * np.sin(Y[0]])
